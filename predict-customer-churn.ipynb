# %%
import numpy as np 
import pandas as pd 
import os

# Machine learning libraries 
from sklearn.linear_model import LogisticRegression

# %%
testDataset =  pd.read_csv('/kaggle/input/competitions/playground-series-s6e3/test.csv')

trainDataset = pd.read_csv('/kaggle/input/competitions/playground-series-s6e3/train.csv')
